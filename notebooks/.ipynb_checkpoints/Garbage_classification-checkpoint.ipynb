# %% [markdown]
# # ✨🌍 **Classification des ordures** 🌍✨

# %% [markdown]
# ## 🧑‍🤝‍🧑 Membres du groupe

# %% [markdown]
# 1. 👤 FATOU MBOUP
# 2. 👤 FATOU KINÉ NDIAYE
# 3. 👤 BINTOU TENNING NGOM

# %% [markdown]
# ## 📄✨ Description du projet

# %% [markdown]
# Ce projet a pour objectif de classifier les ordures en différentes catégories telles que plastique, papier, métal, déchets, verre, et carton. Nous essaierons de développer un modèle de classification précis et efficace.

# %% [markdown]
# ## 📂🔗 **Montage de Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project
# Out:
# /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project

# %%
pwd
# Out:
# '/content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project'

# %% [markdown]
# ## 📦✨ Installation des Bibliothèques pour Colab

# %%
#For colab
# !pip install pyngrok

#For Colab
# !pip install pendulum
#For Colab
# !pip install ydata_profiling
# !pip install mlflow
#For Colab
# !pip install loguru
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Requirement already satisfied: pendulum in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: python-dateutil>=2.6 in /usr/local/lib/python3.10/dist-packages (from pendulum) (2.8.2)
# Requirement already satisfied: tzdata>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pendulum) (2024.1)
# Requirement already satisfied: time-machine>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from pendulum) (2.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.6->pendulum) (1.16.0)
# Requirement already satisfied: ydata_profiling in /usr/local/lib/python3.10/dist-packages (4.9.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (2.1.4)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (0.13.1)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata_profiling) (1.6.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata_profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata_profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata_profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (24.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.10/dist-packages (2.15.1)
# Requirement already satisfied: mlflow-skinny==2.15.1 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.15.1)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.13.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.3)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.7.1)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.1.4)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow) (14.0.2)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.2.4)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.3.2)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.0.31)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.1.4)
# Requirement already satisfied: gunicorn<23 in /usr/local/lib/python3.10/dist-packages (from mlflow) (22.0.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (2.2.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (0.29.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (7.2.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (1.26.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (24.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (3.20.3)
# Requirement already satisfied: pytz<2025 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (2024.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.15.1->mlflow) (0.5.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.10/dist-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.10/dist-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /usr/local/lib/python3.10/dist-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.10/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (2.27.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow-skinny==2.15.1->mlflow) (3.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (0.47b0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (2024.7.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.6.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.10/dist-packages (0.7.2)

# %% [markdown]
# ## 📥🔧 Importation des Modules

# %%
# Magics
# %reload_ext autoreload
# %autoreload 2

# Importations de bibliothèques Python
import cv2
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import os
import pandas as pd
import pendulum
import random
import sys
import tensorflow as tf
from collections import Counter
from datetime import datetime
from loguru import logger
from pathlib import Path
from pyngrok import ngrok
from sklearn.metrics import accuracy_score, auc, log_loss, precision_score, recall_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, label_binarize, LabelEncoder
from sklearn.utils import shuffle
from tensorflow.keras.applications import MobileNetV2, VGG16, DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import Accuracy, AUC, Precision, Recall, SparseCategoricalAccuracy
from tensorflow.keras.models import Model, save_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from torch.utils.data import DataLoader, TensorDataset
from torchvision import models
from tqdm import tqdm

# Importations de mlflow
import mlflow.keras
from mlflow import log_artifacts, log_metric, log_param
from mlflow.models import infer_signature
from mlflow.tracking import MlflowClient
import mlflow.pytorch  # Importer mlflow.pytorch

# Importations des modules personnalisés
from settings.config import *
from src.make_dataset import *
from src.make_model_mobilenet import *
from src.make_model_vgg16 import *
from src.make_model_densenet import *

# Importations de PyTorch

import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## 📊📖 Chargement et Prétraitement des données

# %% [markdown]
# ### 🔗✨ Settings ✨🔗

# %%
# Set logging format
log_fmt = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS!UTC}</green> | <level>{level: <8}</level> | <cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> - {message}"
logger.configure(handlers=[{"sink": sys.stderr, "format": log_fmt}])

# current data
CURRENT_DATE = pendulum.now(tz="UTC")

# directories
PROJECT_DIR = Path.cwd().parent
REPORTS_DIR = Path(PROJECT_DIR, "reports")

logger.info(f"\nProject directory: {PROJECT_DIR} \nReports dir: {REPORTS_DIR}")
# Out:
# 2024-08-07 18:30:49.223 | INFO     | __main__:<cell line: 12>:12 -
# Project directory: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps
# Reports dir: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/reports

# %% [markdown]
# ### 🔋✨ Load Data ✨🔋

# %%
base_dir = 'Garbage_classification'

# %%
imgs_data,labels_data, class_names = load_data(base_dir)
# Out:
# Loading glass: 100%|██████████| 501/501 [00:05<00:00, 92.30it/s]
# Loading trash: 100%|██████████| 137/137 [00:01<00:00, 88.91it/s]
# Loading plastic: 100%|██████████| 482/482 [00:08<00:00, 58.66it/s]
# Loading cardboard: 100%|██████████| 403/403 [00:04<00:00, 82.03it/s]
# Loading metal: 100%|██████████| 410/410 [00:07<00:00, 57.59it/s]
# Loading paper: 100%|██████████| 594/594 [00:06<00:00, 89.60it/s]

# %%
class_names
# Out:
# ['glass', 'trash', 'plastic', 'cardboard', 'metal', 'paper']

# %% [markdown]
# 📸✨ Visualization & Preprocessing ✨📸

# %% [markdown]
# ### 📖✨ Visualization ✨📖

# %%
visualize_class_distribution(labels_data, class_names)

# %%
plot_images_from_subfolders(base_dir)
# Out:
# Images de: glass
# Images de: trash
# Images de: plastic
# Images de: cardboard
# Images de: metal
# Images de: paper

# %%
img_dimensions(base_dir)
# Out:
# Analyse des images en: Garbage_classification/glass
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 501
#
#
# Analyse des images en: Garbage_classification/trash
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 137
#
#
# Analyse des images en: Garbage_classification/plastic
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 482
#
#
# Analyse des images en: Garbage_classification/cardboard
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 403
#
#
# Analyse des images en: Garbage_classification/metal
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 410
#
#
# Analyse des images en: Garbage_classification/paper
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 594

# %% [markdown]
# ### 📊✨ Normalization & Encoding ✨📊

# %%
processed_dir = "/content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images"
data, labels = process_dataset(base_dir, processed_dir)
# Out:
# Classe cardboard: 403 processed
# Classe glass: 501 processed
# Classe metal: 410 processed
# Classe paper: 594 processed
# Classe plastic: 482 processed
# Classe trash: 137 processed

# %%
img_dimensions(processed_dir)
# Out:
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/cardboard
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 403
#
#
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/glass
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 501
#
#
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/metal
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 410
#
#
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/paper
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 594
#
#
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/plastic
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 482
#
#
# Analyse des images en: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/processed_images/trash
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 137

# %%
plot_images_from_subfolders(processed_dir)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convertit la liste data en un tableau NumPy.
# Spécifie le type de données comme "float32" pour la précision et l'efficacité
# Divise toutes les valeurs par 255.0, normalisant ainsi les pixels dans la plage [0, 1]
data = np.array(data, dtype="float32") / 255.0
#Convertit la liste labels en un tableau NumPy pour un traitement ultérieur efficace.
labels = np.array(labels)
# Crée une instance de LabelBinarizer de scikit-learn qui va encoder les étiquettes textuelles en format numérique
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
#Affiche la première étiquette encodée pour vérification.
print(labels[0])
# Out:
# [1 0 0 0 0 0]

# %% [markdown]
# ### 📈✨Apply augmentation to the dataset ✨📈

# %%
final_imgs_data, final_labels_data = increase_dataset(data, labels)

# %%
print("Size before augmentation : ",data.shape[0])
print("Size After augmentation : ",final_imgs_data.shape[0])
# Out:
# Size before augmentation :  2527
# Size After augmentation :  5054

# %% [markdown]
# ### ✂️✨ Split Data ✨✂️

# %%
x_train, x_val, x_test, y_train, y_val, y_test = split_data(final_imgs_data, final_labels_data)

# %%
# Utilisation de la fonction
classes = np.arange(labels.shape[1])

# Vérifiez les distributions des classes dans chaque ensemble
train_class_distribution = check_class_distribution(y_train, classes)
val_class_distribution = check_class_distribution(y_val, classes)
test_class_distribution = check_class_distribution(y_test, classes)

print("Distribution des classes dans l'ensemble d'entraînement :", train_class_distribution)
print("Distribution des classes dans l'ensemble de validation :", val_class_distribution)
print("Distribution des classes dans l'ensemble de test :", test_class_distribution)
# Out:
# Distribution des classes dans l'ensemble d'entraînement : {0: 468, 1: 589, 2: 491, 3: 716, 4: 606, 5: 162}
# Distribution des classes dans l'ensemble de validation : {0: 162, 1: 197, 2: 165, 3: 252, 4: 179, 5: 56}
# Distribution des classes dans l'ensemble de test : {0: 176, 1: 216, 2: 164, 3: 220, 4: 179, 5: 56}

# %% [markdown]
# ## 🔋✨ Chargement et Config pour les modèles ✨🔋

# %% [markdown]
# ### 📈✨ Définition de eval_metrics ✨📈

# %%
def eval_metrics(y_true, y_pred, y_pred_proba):
    """
    Calcule les métriques pour une classification multiclasse.

    param y_true: Les vraies étiquettes
    param y_pred: Les prédictions du modèle
    param y_pred_proba: Les probabilités prédites par le modèle
    return: Un dictionnaire contenant les métriques calculées
    """
    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Precision, Recall
    # y_true et y_pred sont les labels réels et prédits respectivement
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Log Loss
    logloss = log_loss(y_true, y_pred_proba)

    # ROC AUC (one-vs-rest)
    n_classes = y_pred_proba.shape[1]
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    roc_auc = {}
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
        roc_auc[i] = auc(fpr, tpr)

    # Moyenne des ROC AUC
    mean_roc_auc = np.mean(list(roc_auc.values()))

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'log_loss': logloss,
        'roc_auc': roc_auc,
        'mean_roc_auc': mean_roc_auc
    }

# %% [markdown]
# ### ⚙️✨ Définition des params des modèles ✨⚙️

# %% [markdown]
# #### 📖✨ Define models and parameters to benchmark ✨📖

# %%
# Define models and parameters to benchmark
ESTIMATOR_PARAMS = {
                VGG16.__name__: {"estimator": VGG16,
                                 "params": VGG16_CONFIG
                                     },

                MobileNetV2.__name__: {"estimator": MobileNetV2,
                                       "params": MOBILENETV2_CONFIG
                                           }
                    ,
                DenseNet121.__name__: {"estimator": DenseNet121, "params": DENSENET_CONFIG
                                                      }
}

ESTIMATOR_PARAMS
# Out:
# {'VGG16': {'estimator': <function keras.src.applications.vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', name='vgg16')>,
#   'params': {'input_shape': (128, 128, 3),
#    'num_classes': 6,
#    'learning_rate': 1e-05,
#    'batch_size': 32,
#    'pretrained': True,
#    'epochs': 50}},
#  'MobileNetV2': {'estimator': <function keras.src.applications.mobilenet_v2.MobileNetV2(input_shape=None, alpha=1.0, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax', name=None)>,
#   'params': {'input_shape': (128, 128, 3),
#    'num_classes': 6,
#    'learning_rate': 0.0001,
#    'patience': 5,
#    'epochs': 50}},
#  'DenseNet121': {'estimator': <function keras.src.applications.densenet.DenseNet121(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', name='densenet121')>,
#   'params': {'num_classes': 6,
#    'dropout_rate': 0.5,
#    'min_lr': 1e-08,
#    'monitor': 'val_accuracy',
#    'factor': 0.15,
#    'patience': 6,
#    'learning_rate': 0.001,
#    'batch_size': 64,
#    'epochs': 50}}}

# %%
for model_name, model_configs in ESTIMATOR_PARAMS.items():
    estimator = model_configs["estimator"]
    params = model_configs["params"]

    print(f"Model Name: {model_name}")
    print(f"Estimator: {estimator}")
    print(f"Params: {params}")
    print("=" * 40)
# Out:
# Model Name: VGG16
# Estimator: <function VGG16 at 0x7a3b5d47bc70>
# Params: {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 1e-05, 'batch_size': 32, 'pretrained': True, 'epochs': 50}
# ========================================
# Model Name: MobileNetV2
# Estimator: <function MobileNetV2 at 0x7a3b5d479870>
# Params: {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 0.0001, 'patience': 5, 'epochs': 50}
# ========================================
# Model Name: DenseNet121
# Estimator: <function DenseNet121 at 0x7a3b5d64f0a0>
# Params: {'num_classes': 6, 'dropout_rate': 0.5, 'min_lr': 1e-08, 'monitor': 'val_accuracy', 'factor': 0.15, 'patience': 6, 'learning_rate': 0.001, 'batch_size': 64, 'epochs': 50}
# ========================================

# %% [markdown]
# ### 🔆✨ Config For MLFLOW ✨🔆

# %%
# Set the tracking server to be localhost with sqlite as tracking store
local_registry = "sqlite:///mlruns.db"
print(f"Running local model registry={local_registry}")
mlflow.set_tracking_uri(local_registry)
# Out:
# Running local model registry=sqlite:///mlruns.db

# %% [markdown]
# #### Create an experiment

# %%
# Create an experiment if not exists
exp_name = "garbage_classification"
experiment = mlflow.get_experiment_by_name(exp_name)
if not experiment:
    experiment_id = mlflow.create_experiment(exp_name)
else:
    experiment_id = experiment.experiment_id

logger.info(f"Experience id: {experiment_id}")
# Out:
# 2024-08-07 18:32:53.037 | INFO     | __main__:<cell line: 9>:9 - Experience id: 1

# %%
# Créer et configurer le modèle
def run_experiment(experiment_id):
    global x_train, x_val, x_test, y_train, y_val, y_test

    for model_name, model_configs in ESTIMATOR_PARAMS.items():
        logger.info(f"{model_name} \n{model_configs}")

        #estimator = model_configs["estimator"]
        params = model_configs["params"]
        print("params['epochs'] : ",params['epochs'])
        with mlflow.start_run(run_name=f"garbage_classification_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
                             experiment_id=experiment_id,
                              tags={"version": "v1", "priority": "P1"},
                              description="garbage classification modeling",) as run:
            # Enregistre le paramètre du modèle (si applicable)
            mlflow.log_param("model", model_name)
            #mlflow.log_param("input_shape", params["input_shape"])
            epoch_number=params["epochs"]
            mlflow.log_params(params)

            if model_name == "DenseNet121":
                DenseNet_model_path="registered_models"
                # DenseNet
                model, x_train, x_val, x_test, y_train, y_val, y_test = build_densenet_model(DENSENET_CONFIG, data, labels)
                # Utilisation de la fonction pour entraîner le modèle et récupérer l'historique et les paramètres
                history, training_params = train_densenet_model(model, DENSENET_CONFIG, x_train, y_train, x_val, y_val,model_path=DenseNet_model_path)

                # Utilisation de la fonction
                y_pred_proba = model.predict(x_test)  # Probabilités prédites
                y_pred = np.argmax(y_pred_proba, axis=1)  # Classes prédites

                if y_test.ndim == 2:
                    y_test2 = np.argmax(y_test, axis=1)

                # Appeler la fonction eval_metrics
                metrics = eval_metrics(y_test2, y_pred, y_pred_proba)

                # Enregistrer le modèle avec la signature
                signature = infer_signature(x_test, y_pred_proba)
                #mlflow.keras.log_model(model, artifact_path="model", signature=signature)
                mlflow.keras.log_model(model, artifact_path="model", signature=signature, registered_model_name=model_name)

            # Pour MobileNetV2
            elif model_name == "MobileNetV2":

                patience=params["patience"]

                # Créer le modèle
                model, params = create_mobilenetv2_model(params["input_shape"], params["num_classes"], params["learning_rate"])

                # Entraîner le modèle
                history = train_mobilenetv2_model(model, x_train, y_train, x_val, y_val, epoch_number, patience)

                # Tester le modèle
                results, y_pred_proba = test_mobilenetv2_model(model, x_test, y_test,class_names)


                # Extraire les classes prédites et réelles
                y_pred = [class_names.index(pred) for pred, _ in results]
                y_true = [class_names.index(real) for _, real in results]

                # Évaluer les métriques du modèle
                metrics = eval_metrics(y_true, y_pred, y_pred_proba)

                # Enregistrer le modèle avec la signature
                signature = infer_signature(x_test, y_pred_proba)
                #mlflow.keras.log_model(model, artifact_path="model", signature=signature)
                mlflow.keras.log_model(model, artifact_path="model", signature=signature, registered_model_name=model_name)

            elif model_name == "VGG16":
                # VGG16 example
                model = create_vgg16_model(VGG16_CONFIG)

                train_loader, val_loader, test_loader = create_data_loaders_for_vgg16(x_train, x_val, x_test, y_train, y_val, y_test,VGG16_CONFIG)
                trained_vgg16 = train_vgg16_model(model, train_loader, val_loader, VGG16_CONFIG)

                # Utilisation de la fonction
                y_pred_proba,metrics = test_model_vgg16(trained_vgg16, test_loader)
                #print("Metrics on the test set:")
                #print(metrics)
                # Enregistrer le modèle avec la signature
                signature = infer_signature(x_test, y_pred_proba)
                # mlflow.pytorch.log_model pour les modèles PyTorch
                mlflow.pytorch.log_model(model, artifact_path="model", signature=signature, registered_model_name=model_name)

            # Log des métriques
            mlflow.log_metric("test_accuracy", metrics['accuracy'])
            mlflow.log_metric("test_precision", metrics['precision'])
            mlflow.log_metric("test_recall", metrics['recall'])
            mlflow.log_metric("test_log_loss", metrics['log_loss'])
            mlflow.log_metric("test_mean_roc_auc", metrics['mean_roc_auc'])

            # Log des ROC AUC pour chaque classe
            for class_index, class_roc_auc in metrics['roc_auc'].items():
                mlflow.log_metric(f"test_roc_auc_class_{class_index}", class_roc_auc)

            if not os.path.exists("outputs"):
                os.makedirs("outputs")
            with open("outputs/test.txt", "w") as f:
                f.write("Looks, like I logged to the local store!")
            log_artifacts("outputs")
            shutil.rmtree('outputs')

            print(f"Model run logged to MLflow with run_id: {run.info.run_id}")

# %%
# Exécuter l'expérience
run_experiment(experiment_id)
# Out:
# 2024-08-07 18:32:53.199 | INFO     | __main__:run_experiment:6 - VGG16
# {'estimator': <function VGG16 at 0x7a3b5d47bc70>, 'params': {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 1e-05, 'batch_size': 32, 'pretrained': True, 'epochs': 50}}
# params['epochs'] :  50
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Nombre de batches dans le DataLoader d'entraînement : 95
# Nombre de batches dans le DataLoader de validation : 32
# Nombre de batches dans le DataLoader de test : 32
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50 - Loss: 1.5753, Accuracy: 33.91%
# Validation Metrics - Accuracy: 0.4372, Precision: 0.4963, Recall: 0.4372, Log Loss: 1.3602, Mean ROC AUC: 0.7540
# Epoch 2/50 - Loss: 1.2598, Accuracy: 48.32%
# Validation Metrics - Accuracy: 0.5074, Precision: 0.6287, Recall: 0.5074, Log Loss: 1.2119, Mean ROC AUC: 0.8050
# Epoch 3/50 - Loss: 1.0886, Accuracy: 54.75%
# Validation Metrics - Accuracy: 0.5292, Precision: 0.6541, Recall: 0.5292, Log Loss: 1.1431, Mean ROC AUC: 0.8224
# Epoch 4/50 - Loss: 1.0037, Accuracy: 57.32%
# Validation Metrics - Accuracy: 0.5124, Precision: 0.6187, Recall: 0.5124, Log Loss: 1.1433, Mean ROC AUC: 0.8231
# Epoch 5/50 - Loss: 0.9211, Accuracy: 60.26%
# Validation Metrics - Accuracy: 0.5193, Precision: 0.6786, Recall: 0.5193, Log Loss: 1.1103, Mean ROC AUC: 0.8289
# Epoch 6/50 - Loss: 0.8517, Accuracy: 63.98%
# Validation Metrics - Accuracy: 0.5203, Precision: 0.6832, Recall: 0.5203, Log Loss: 1.1184, Mean ROC AUC: 0.8318
# Epoch 7/50 - Loss: 0.8237, Accuracy: 63.23%
# Validation Metrics - Accuracy: 0.5321, Precision: 0.6655, Recall: 0.5321, Log Loss: 1.1468, Mean ROC AUC: 0.8262
# Epoch 8/50 - Loss: 0.8003, Accuracy: 65.47%
# Validation Metrics - Accuracy: 0.5223, Precision: 0.6714, Recall: 0.5223, Log Loss: 1.1635, Mean ROC AUC: 0.8259
# Epoch 9/50 - Loss: 0.7792, Accuracy: 65.47%
# Validation Metrics - Accuracy: 0.5371, Precision: 0.6748, Recall: 0.5371, Log Loss: 1.1715, Mean ROC AUC: 0.8256
# Epoch 10/50 - Loss: 0.7651, Accuracy: 65.40%
# Validation Metrics - Accuracy: 0.5153, Precision: 0.6754, Recall: 0.5153, Log Loss: 1.1804, Mean ROC AUC: 0.8228
# Epoch 11/50 - Loss: 0.7452, Accuracy: 66.85%
# Validation Metrics - Accuracy: 0.5351, Precision: 0.6513, Recall: 0.5351, Log Loss: 1.2098, Mean ROC AUC: 0.8281
# Epoch 12/50 - Loss: 0.7430, Accuracy: 66.66%
# Validation Metrics - Accuracy: 0.5213, Precision: 0.6722, Recall: 0.5213, Log Loss: 1.2435, Mean ROC AUC: 0.8250
# Epoch 13/50 - Loss: 0.7417, Accuracy: 67.22%
# Validation Metrics - Accuracy: 0.5203, Precision: 0.6642, Recall: 0.5203, Log Loss: 1.2310, Mean ROC AUC: 0.8256
# Epoch 14/50 - Loss: 0.7347, Accuracy: 67.78%
# Validation Metrics - Accuracy: 0.5312, Precision: 0.6851, Recall: 0.5312, Log Loss: 1.2377, Mean ROC AUC: 0.8243
# Epoch 15/50 - Loss: 0.7207, Accuracy: 68.50%
# Validation Metrics - Accuracy: 0.5193, Precision: 0.6683, Recall: 0.5193, Log Loss: 1.2615, Mean ROC AUC: 0.8252
# Epoch 16/50 - Loss: 0.7094, Accuracy: 68.21%
# Validation Metrics - Accuracy: 0.5242, Precision: 0.6267, Recall: 0.5242, Log Loss: 1.2794, Mean ROC AUC: 0.8228
# Epoch 17/50 - Loss: 0.7058, Accuracy: 68.73%
# Validation Metrics - Accuracy: 0.5134, Precision: 0.6580, Recall: 0.5134, Log Loss: 1.3076, Mean ROC AUC: 0.8187
# Epoch 18/50 - Loss: 0.7063, Accuracy: 67.48%
# Validation Metrics - Accuracy: 0.5203, Precision: 0.6735, Recall: 0.5203, Log Loss: 1.3199, Mean ROC AUC: 0.8213
# Epoch 19/50 - Loss: 0.6957, Accuracy: 68.63%
# Validation Metrics - Accuracy: 0.5213, Precision: 0.6189, Recall: 0.5213, Log Loss: 1.3787, Mean ROC AUC: 0.8197
# Epoch 20/50 - Loss: 0.7061, Accuracy: 68.34%
# Validation Metrics - Accuracy: 0.5193, Precision: 0.6381, Recall: 0.5193, Log Loss: 1.3898, Mean ROC AUC: 0.8230
# Epoch 21/50 - Loss: 0.6899, Accuracy: 69.85%
# Validation Metrics - Accuracy: 0.5242, Precision: 0.6729, Recall: 0.5242, Log Loss: 1.3602, Mean ROC AUC: 0.8273
# Epoch 22/50 - Loss: 0.6804, Accuracy: 69.46%
# Validation Metrics - Accuracy: 0.5213, Precision: 0.6699, Recall: 0.5213, Log Loss: 1.3976, Mean ROC AUC: 0.8260
# Epoch 23/50 - Loss: 0.6815, Accuracy: 69.13%
# Validation Metrics - Accuracy: 0.5262, Precision: 0.6363, Recall: 0.5262, Log Loss: 1.4474, Mean ROC AUC: 0.8204
# Epoch 24/50 - Loss: 0.6864, Accuracy: 69.33%
# Validation Metrics - Accuracy: 0.5262, Precision: 0.6460, Recall: 0.5262, Log Loss: 1.5260, Mean ROC AUC: 0.8164
# Epoch 25/50 - Loss: 0.6841, Accuracy: 68.60%
# Validation Metrics - Accuracy: 0.5232, Precision: 0.6300, Recall: 0.5232, Log Loss: 1.4078, Mean ROC AUC: 0.8176
# Epoch 26/50 - Loss: 0.6827, Accuracy: 69.62%
# Validation Metrics - Accuracy: 0.5321, Precision: 0.6447, Recall: 0.5321, Log Loss: 1.4383, Mean ROC AUC: 0.8175
# Epoch 27/50 - Loss: 0.6709, Accuracy: 70.45%
# Validation Metrics - Accuracy: 0.5292, Precision: 0.6469, Recall: 0.5292, Log Loss: 1.4387, Mean ROC AUC: 0.8158
# Epoch 28/50 - Loss: 0.6702, Accuracy: 69.33%
# Validation Metrics - Accuracy: 0.5272, Precision: 0.6377, Recall: 0.5272, Log Loss: 1.4867, Mean ROC AUC: 0.8176
# Epoch 29/50 - Loss: 0.6715, Accuracy: 69.79%
# Validation Metrics - Accuracy: 0.5094, Precision: 0.6267, Recall: 0.5094, Log Loss: 1.6143, Mean ROC AUC: 0.8088
# Epoch 30/50 - Loss: 0.6756, Accuracy: 69.72%
# Validation Metrics - Accuracy: 0.5183, Precision: 0.6277, Recall: 0.5183, Log Loss: 1.4646, Mean ROC AUC: 0.8091
# Epoch 31/50 - Loss: 0.6716, Accuracy: 70.35%
# Validation Metrics - Accuracy: 0.5252, Precision: 0.6349, Recall: 0.5252, Log Loss: 1.4461, Mean ROC AUC: 0.8144
# Epoch 32/50 - Loss: 0.6645, Accuracy: 69.79%
# Validation Metrics - Accuracy: 0.5282, Precision: 0.6587, Recall: 0.5282, Log Loss: 1.5363, Mean ROC AUC: 0.8111
# Epoch 33/50 - Loss: 0.6638, Accuracy: 69.20%
# Validation Metrics - Accuracy: 0.5321, Precision: 0.6651, Recall: 0.5321, Log Loss: 1.4899, Mean ROC AUC: 0.8129
# Epoch 34/50 - Loss: 0.6639, Accuracy: 70.55%
# Validation Metrics - Accuracy: 0.5262, Precision: 0.6369, Recall: 0.5262, Log Loss: 1.5796, Mean ROC AUC: 0.8140
# Epoch 35/50 - Loss: 0.6621, Accuracy: 69.46%
# Validation Metrics - Accuracy: 0.5232, Precision: 0.6316, Recall: 0.5232, Log Loss: 1.5803, Mean ROC AUC: 0.8102
# Epoch 36/50 - Loss: 0.6600, Accuracy: 69.23%
# Validation Metrics - Accuracy: 0.5272, Precision: 0.6371, Recall: 0.5272, Log Loss: 1.6163, Mean ROC AUC: 0.8128
# Epoch 37/50 - Loss: 0.6609, Accuracy: 70.35%
# Validation Metrics - Accuracy: 0.5430, Precision: 0.6798, Recall: 0.5430, Log Loss: 1.6090, Mean ROC AUC: 0.8164
# Epoch 38/50 - Loss: 0.6741, Accuracy: 69.36%
# Validation Metrics - Accuracy: 0.5223, Precision: 0.6318, Recall: 0.5223, Log Loss: 1.5421, Mean ROC AUC: 0.8125
# Epoch 39/50 - Loss: 0.6610, Accuracy: 69.46%
# Validation Metrics - Accuracy: 0.5223, Precision: 0.6263, Recall: 0.5223, Log Loss: 1.5452, Mean ROC AUC: 0.8172
# Epoch 40/50 - Loss: 0.6613, Accuracy: 70.15%
# Validation Metrics - Accuracy: 0.5114, Precision: 0.6297, Recall: 0.5114, Log Loss: 1.7019, Mean ROC AUC: 0.8106
# Epoch 41/50 - Loss: 0.6639, Accuracy: 69.85%
# Validation Metrics - Accuracy: 0.5232, Precision: 0.6326, Recall: 0.5232, Log Loss: 1.5350, Mean ROC AUC: 0.8199
# Epoch 42/50 - Loss: 0.6735, Accuracy: 69.82%
# Validation Metrics - Accuracy: 0.5292, Precision: 0.6430, Recall: 0.5292, Log Loss: 1.5551, Mean ROC AUC: 0.8148
# Epoch 43/50 - Loss: 0.6595, Accuracy: 70.78%
# Validation Metrics - Accuracy: 0.5262, Precision: 0.6344, Recall: 0.5262, Log Loss: 1.5569, Mean ROC AUC: 0.8167
# Epoch 44/50 - Loss: 0.6569, Accuracy: 70.02%
# Validation Metrics - Accuracy: 0.5242, Precision: 0.6518, Recall: 0.5242, Log Loss: 1.5676, Mean ROC AUC: 0.8185
# Epoch 45/50 - Loss: 0.6583, Accuracy: 69.62%
# Validation Metrics - Accuracy: 0.5163, Precision: 0.6653, Recall: 0.5163, Log Loss: 1.6218, Mean ROC AUC: 0.8167
# Epoch 46/50 - Loss: 0.6626, Accuracy: 69.95%
# Validation Metrics - Accuracy: 0.5203, Precision: 0.6749, Recall: 0.5203, Log Loss: 1.5343, Mean ROC AUC: 0.8203
# Epoch 47/50 - Loss: 0.6561, Accuracy: 70.18%
# Validation Metrics - Accuracy: 0.5282, Precision: 0.6405, Recall: 0.5282, Log Loss: 1.6401, Mean ROC AUC: 0.8136
# Epoch 48/50 - Loss: 0.6562, Accuracy: 70.02%
# Validation Metrics - Accuracy: 0.5321, Precision: 0.6443, Recall: 0.5321, Log Loss: 1.6566, Mean ROC AUC: 0.8163
# Epoch 49/50 - Loss: 0.6548, Accuracy: 70.25%
# Validation Metrics - Accuracy: 0.5321, Precision: 0.6446, Recall: 0.5321, Log Loss: 1.6625, Mean ROC AUC: 0.8168
# Epoch 50/50 - Loss: 0.6714, Accuracy: 70.38%
# Validation Metrics - Accuracy: 0.5183, Precision: 0.6264, Recall: 0.5183, Log Loss: 1.4502, Mean ROC AUC: 0.8143
# 2024/08/07 18:49:13 WARNING mlflow.utils.requirements_utils: Found torch version (2.3.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.3.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2024/08/07 18:49:22 WARNING mlflow.utils.requirements_utils: Found torchvision version (0.18.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torchvision==0.18.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:32: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# Registered model 'VGG16' already exists. Creating a new version of this model...
# Created version '4' of model 'VGG16'.
# 2024-08-07 18:49:28.077 | INFO     | __main__:run_experiment:6 - MobileNetV2
# {'estimator': <function MobileNetV2 at 0x7a3b5d479870>, 'params': {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 0.0001, 'patience': 5, 'epochs': 50}}
# Model run logged to MLflow with run_id: ca4f1189e9b346269b03d96d7a8647ad
# params['epochs'] :  50
# Epoch 1/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 27s 146ms/step - AUC: 0.6471 - Accuracy: 0.3362 - Precision: 0.8822 - Recall: 0.8395 - log_loss: 1.6267 - loss: 1.6267 - val_AUC: 0.7855 - val_Accuracy: 0.4837 - val_Precision: 0.9013 - val_Recall: 0.9682 - val_log_loss: 1.2820 - val_loss: 1.2825
# Epoch 2/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - AUC: 0.8343 - Accuracy: 0.5414 - Precision: 0.9150 - Recall: 0.8871 - log_loss: 1.1367 - loss: 1.1367 - val_AUC: 0.8058 - val_Accuracy: 0.5124 - val_Precision: 0.9053 - val_Recall: 0.9800 - val_log_loss: 1.2054 - val_loss: 1.2064
# Epoch 3/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - AUC: 0.8605 - Accuracy: 0.5849 - Precision: 0.9114 - Recall: 0.9906 - log_loss: 1.0350 - loss: 1.0350 - val_AUC: 0.8164 - val_Accuracy: 0.5114 - val_Precision: 0.9076 - val_Recall: 0.9600 - val_log_loss: 1.1793 - val_loss: 1.1811
# Epoch 4/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - AUC: 0.8683 - Accuracy: 0.6119 - Precision: 0.9206 - Recall: 0.9895 - log_loss: 0.9983 - loss: 0.9983 - val_AUC: 0.8162 - val_Accuracy: 0.5054 - val_Precision: 0.9066 - val_Recall: 0.9717 - val_log_loss: 1.1701 - val_loss: 1.1722
# Epoch 5/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - AUC: 0.8797 - Accuracy: 0.6235 - Precision: 0.9204 - Recall: 0.9915 - log_loss: 0.9393 - loss: 0.9393 - val_AUC: 0.8216 - val_Accuracy: 0.5094 - val_Precision: 0.9064 - val_Recall: 0.9694 - val_log_loss: 1.1581 - val_loss: 1.1597
# Epoch 6/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - AUC: 0.8892 - Accuracy: 0.6419 - Precision: 0.9150 - Recall: 0.9774 - log_loss: 0.8980 - loss: 0.8980 - val_AUC: 0.8228 - val_Accuracy: 0.5124 - val_Precision: 0.9059 - val_Recall: 0.9753 - val_log_loss: 1.1690 - val_loss: 1.1711
# Epoch 7/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - AUC: 0.8856 - Accuracy: 0.6241 - Precision: 0.9255 - Recall: 0.9889 - log_loss: 0.8972 - loss: 0.8972 - val_AUC: 0.8264 - val_Accuracy: 0.5282 - val_Precision: 0.9053 - val_Recall: 0.9800 - val_log_loss: 1.1449 - val_loss: 1.1465
# Epoch 8/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - AUC: 0.9008 - Accuracy: 0.6527 - Precision: 0.9167 - Recall: 0.9948 - log_loss: 0.8453 - loss: 0.8453 - val_AUC: 0.8256 - val_Accuracy: 0.5232 - val_Precision: 0.9081 - val_Recall: 0.9658 - val_log_loss: 1.1426 - val_loss: 1.1451
# Epoch 9/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - AUC: 0.9051 - Accuracy: 0.6732 - Precision: 0.9227 - Recall: 0.9910 - log_loss: 0.8160 - loss: 0.8160 - val_AUC: 0.8226 - val_Accuracy: 0.5143 - val_Precision: 0.9075 - val_Recall: 0.9706 - val_log_loss: 1.1476 - val_loss: 1.1506
# Epoch 10/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - AUC: 0.9018 - Accuracy: 0.6615 - Precision: 0.9261 - Recall: 0.9948 - log_loss: 0.8433 - loss: 0.8433 - val_AUC: 0.8300 - val_Accuracy: 0.5262 - val_Precision: 0.9098 - val_Recall: 0.9741 - val_log_loss: 1.1561 - val_loss: 1.1577
# Epoch 11/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - AUC: 0.9032 - Accuracy: 0.6537 - Precision: 0.9227 - Recall: 0.9948 - log_loss: 0.8135 - loss: 0.8135 - val_AUC: 0.8294 - val_Accuracy: 0.5094 - val_Precision: 0.9128 - val_Recall: 0.9623 - val_log_loss: 1.1425 - val_loss: 1.1451
# Epoch 12/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - AUC: 0.9049 - Accuracy: 0.6812 - Precision: 0.9300 - Recall: 0.9961 - log_loss: 0.7832 - loss: 0.7832 - val_AUC: 0.8279 - val_Accuracy: 0.5312 - val_Precision: 0.9069 - val_Recall: 0.9753 - val_log_loss: 1.1513 - val_loss: 1.1542
# Epoch 13/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - AUC: 0.9047 - Accuracy: 0.6593 - Precision: 0.9255 - Recall: 0.9835 - log_loss: 0.8122 - loss: 0.8122 - val_AUC: 0.8272 - val_Accuracy: 0.5262 - val_Precision: 0.9094 - val_Recall: 0.9694 - val_log_loss: 1.1672 - val_loss: 1.1690
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ...
# Epoch 3/50
#
# Epoch 3: val_loss improved from 13.50092 to 10.86142, saving model to model_best.keras
# 23/23 - 19s - 805ms/step - AUC: 0.8967 - Precision: 0.7006 - Recall: 0.5968 - accuracy: 0.6513 - loss: 1.1813 - val_AUC: 0.5107 - val_Precision: 0.1719 - val_Recall: 0.1719 - val_accuracy: 0.1719 - val_loss: 10.8614 - learning_rate: 0.0010
# Epoch 4/50
#
# Epoch 4: val_loss improved from 10.86142 to 10.41497, saving model to model_best.keras
# 23/23 - 8s - 365ms/step - AUC: 0.9087 - Precision: 0.7273 - Recall: 0.6250 - accuracy: 0.6875 - loss: 1.1124 - val_AUC: 0.5139 - val_Precision: 0.1719 - val_Recall: 0.1719 - val_accuracy: 0.1719 - val_loss: 10.4150 - learning_rate: 0.0010
# Epoch 5/50
#
# Epoch 5: val_loss improved from 10.41497 to 5.33062, saving model to model_best.keras
# 23/23 - 18s - 761ms/step - AUC: 0.9326 - Precision: 0.7623 - Recall: 0.6430 - accuracy: 0.6975 - loss: 0.8741 - val_AUC: 0.5243 - val_Precision: 0.1255 - val_Recall: 0.1225 - val_accuracy: 0.1245 - val_loss: 5.3306 - learning_rate: 0.0010
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 5.33062
# 23/23 - 1s - 41ms/step - AUC: 0.9468 - Precision: 0.8214 - Recall: 0.7188 - accuracy: 0.7812 - loss: 0.7251 - val_AUC: 0.5292 - val_Precision: 0.1354 - val_Recall: 0.1324 - val_accuracy: 0.1344 - val_loss: 5.5745 - learning_rate: 0.0010
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 5.33062
# 23/23 - 10s - 438ms/step - AUC: 0.9605 - Precision: 0.8333 - Recall: 0.7512 - accuracy: 0.7891 - loss: 0.6435 - val_AUC: 0.5750 - val_Precision: 0.1856 - val_Recall: 0.1838 - val_accuracy: 0.1877 - val_loss: 6.4164 - learning_rate: 0.0010
# Epoch 8/50
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 8: val_loss did not improve from 5.33062
# 23/23 - 1s - 32ms/step - AUC: 0.9443 - Precision: 0.8214 - Recall: 0.7188 - accuracy: 0.7500 - loss: 0.7656 - val_AUC: 0.5695 - val_Precision: 0.1827 - val_Recall: 0.1798 - val_accuracy: 0.1897 - val_loss: 6.7910 - learning_rate: 0.0010
# Epoch 9/50
#
# Epoch 9: val_loss improved from 5.33062 to 2.19867, saving model to model_best.keras
# 23/23 - 30s - 1s/step - AUC: 0.9733 - Precision: 0.8690 - Recall: 0.8001 - accuracy: 0.8339 - loss: 0.4918 - val_AUC: 0.7669 - val_Precision: 0.4873 - val_Recall: 0.4170 - val_accuracy: 0.4368 - val_loss: 2.1987 - learning_rate: 1.5000e-04
# Epoch 10/50
#
# Epoch 10: val_loss improved from 2.19867 to 2.13737, saving model to model_best.keras
# 23/23 - 11s - 490ms/step - AUC: 0.9744 - Precision: 0.8750 - Recall: 0.7656 - accuracy: 0.8125 - loss: 0.5147 - val_AUC: 0.7731 - val_Precision: 0.4965 - val_Recall: 0.4229 - val_accuracy: 0.4407 - val_loss: 2.1374 - learning_rate: 1.5000e-04
# Epoch 11/50
#
# Epoch 11: val_loss improved from 2.13737 to 1.73198, saving model to model_best.keras
# 23/23 - 19s - 847ms/step - AUC: 0.9812 - Precision: 0.8883 - Recall: 0.8167 - accuracy: 0.8553 - loss: 0.4115 - val_AUC: 0.8194 - val_Precision: 0.5511 - val_Recall: 0.4585 - val_accuracy: 0.5020 - val_loss: 1.7320 - learning_rate: 1.5000e-04
# Epoch 12/50
#
# Epoch 12: val_loss improved from 1.73198 to 1.72703, saving model to model_best.keras
# 23/23 - 18s - 800ms/step - AUC: 0.9931 - Precision: 0.9310 - Recall: 0.8438 - accuracy: 0.9219 - loss: 0.2735 - val_AUC: 0.8202 - val_Precision: 0.5521 - val_Recall: 0.4605 - val_accuracy: 0.5040 - val_loss: 1.7270 - learning_rate: 1.5000e-04
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 1.72703
# 23/23 - 13s - 556ms/step - AUC: 0.9884 - Precision: 0.9129 - Recall: 0.8663 - accuracy: 0.8890 - loss: 0.3263 - val_AUC: 0.8238 - val_Precision: 0.5455 - val_Recall: 0.4743 - val_accuracy: 0.4980 - val_loss: 1.7620 - learning_rate: 1.5000e-04
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 1.72703
# 23/23 - 1s - 38ms/step - AUC: 0.9911 - Precision: 0.9048 - Recall: 0.8906 - accuracy: 0.9062 - loss: 0.2812 - val_AUC: 0.8242 - val_Precision: 0.5430 - val_Recall: 0.4743 - val_accuracy: 0.4980 - val_loss: 1.7701 - learning_rate: 1.5000e-04
# Epoch 15/50
#
# Epoch 15: val_loss improved from 1.72703 to 1.42088, saving model to model_best.keras
# 23/23 - 21s - 909ms/step - AUC: 0.9904 - Precision: 0.9196 - Recall: 0.8746 - accuracy: 0.8952 - loss: 0.2870 - val_AUC: 0.8696 - val_Precision: 0.6236 - val_Recall: 0.5435 - val_accuracy: 0.5771 - val_loss: 1.4209 - learning_rate: 1.5000e-04
# Epoch 16/50
#
# Epoch 16: val_loss improved from 1.42088 to 1.40896, saving model to model_best.keras
# 23/23 - 13s - 545ms/step - AUC: 0.9951 - Precision: 0.9516 - Recall: 0.9219 - accuracy: 0.9219 - loss: 0.2187 - val_AUC: 0.8706 - val_Precision: 0.6253 - val_Recall: 0.5474 - val_accuracy: 0.5771 - val_loss: 1.4090 - learning_rate: 1.5000e-04
# Epoch 17/50
#
# Epoch 17: val_loss improved from 1.40896 to 1.03255, saving model to model_best.keras
# 23/23 - 19s - 811ms/step - AUC: 0.9946 - Precision: 0.9392 - Recall: 0.9042 - accuracy: 0.9207 - loss: 0.2234 - val_AUC: 0.9175 - val_Precision: 0.6973 - val_Recall: 0.6146 - val_accuracy: 0.6522 - val_loss: 1.0326 - learning_rate: 1.5000e-04
# Epoch 18/50
#
# Epoch 18: val_loss improved from 1.03255 to 1.02380, saving model to model_best.keras
# 23/23 - 14s - 602ms/step - AUC: 0.9919 - Precision: 0.9016 - Recall: 0.8594 - accuracy: 0.8906 - loss: 0.2921 - val_AUC: 0.9184 - val_Precision: 0.6949 - val_Recall: 0.6166 - val_accuracy: 0.6561 - val_loss: 1.0238 - learning_rate: 1.5000e-04
# Epoch 19/50
#
# Epoch 19: val_loss improved from 1.02380 to 0.88982, saving model to model_best.keras
# 23/23 - 23s - 993ms/step - AUC: 0.9942 - Precision: 0.9404 - Recall: 0.9132 - accuracy: 0.9235 - loss: 0.2212 - val_AUC: 0.9327 - val_Precision: 0.7550 - val_Recall: 0.6700 - val_accuracy: 0.7115 - val_loss: 0.8898 - learning_rate: 1.5000e-04
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.88982
# 23/23 - 1s - 35ms/step - AUC: 0.9955 - Precision: 0.9516 - Recall: 0.9219 - accuracy: 0.9219 - loss: 0.2036 - val_AUC: 0.9321 - val_Precision: 0.7528 - val_Recall: 0.6680 - val_accuracy: 0.7115 - val_loss: 0.8992 - learning_rate: 1.5000e-04
# Epoch 21/50
#
# Epoch 21: val_loss improved from 0.88982 to 0.88210, saving model to model_best.keras
# 23/23 - 40s - 2s/step - AUC: 0.9965 - Precision: 0.9533 - Recall: 0.9290 - accuracy: 0.9414 - loss: 0.1652 - val_AUC: 0.9352 - val_Precision: 0.7614 - val_Recall: 0.6937 - val_accuracy: 0.7253 - val_loss: 0.8821 - learning_rate: 1.5000e-04
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.88210
# 23/23 - 1s - 33ms/step - AUC: 0.9984 - Precision: 0.9524 - Recall: 0.9375 - accuracy: 0.9375 - loss: 0.1390 - val_AUC: 0.9342 - val_Precision: 0.7575 - val_Recall: 0.6976 - val_accuracy: 0.7253 - val_loss: 0.8863 - learning_rate: 1.5000e-04
# Epoch 23/50
#
# Epoch 23: val_loss improved from 0.88210 to 0.77518, saving model to model_best.keras
# 23/23 - 38s - 2s/step - AUC: 0.9953 - Precision: 0.9422 - Recall: 0.9214 - accuracy: 0.9318 - loss: 0.1885 - val_AUC: 0.9504 - val_Precision: 0.7808 - val_Recall: 0.7391 - val_accuracy: 0.7569 - val_loss: 0.7752 - learning_rate: 1.5000e-04
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.77518
# 23/23 - 1s - 35ms/step - AUC: 0.9993 - Precision: 0.9839 - Recall: 0.9531 - accuracy: 0.9688 - loss: 0.1070 - val_AUC: 0.9513 - val_Precision: 0.7812 - val_Recall: 0.7411 - val_accuracy: 0.7589 - val_loss: 0.7752 - learning_rate: 1.5000e-04
# Epoch 25/50
#
# Epoch 25: val_loss improved from 0.77518 to 0.70182, saving model to model_best.keras
# 23/23 - 42s - 2s/step - AUC: 0.9950 - Precision: 0.9501 - Recall: 0.9325 - accuracy: 0.9414 - loss: 0.1814 - val_AUC: 0.9569 - val_Precision: 0.7996 - val_Recall: 0.7569 - val_accuracy: 0.7747 - val_loss: 0.7018 - learning_rate: 1.5000e-04
# Epoch 26/50
#
# Epoch 26: val_loss improved from 0.70182 to 0.69934, saving model to model_best.keras
# 23/23 - 16s - 691ms/step - AUC: 0.9956 - Precision: 0.9531 - Recall: 0.9531 - accuracy: 0.9531 - loss: 0.2015 - val_AUC: 0.9570 - val_Precision: 0.7975 - val_Recall: 0.7549 - val_accuracy: 0.7727 - val_loss: 0.6993 - learning_rate: 1.5000e-04
# Epoch 27/50
#
# Epoch 27: val_loss improved from 0.69934 to 0.65455, saving model to model_best.keras
# 23/23 - 23s - 997ms/step - AUC: 0.9974 - Precision: 0.9631 - Recall: 0.9524 - accuracy: 0.9600 - loss: 0.1316 - val_AUC: 0.9590 - val_Precision: 0.8037 - val_Recall: 0.7688 - val_accuracy: 0.7866 - val_loss: 0.6546 - learning_rate: 1.5000e-04
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.65455
# 23/23 - 1s - 53ms/step - AUC: 0.9982 - Precision: 0.9531 - Recall: 0.9531 - accuracy: 0.9531 - loss: 0.1355 - val_AUC: 0.9572 - val_Precision: 0.8012 - val_Recall: 0.7648 - val_accuracy: 0.7846 - val_loss: 0.6629 - learning_rate: 1.5000e-04
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.65455
# 23/23 - 25s - 1s/step - AUC: 0.9982 - Precision: 0.9694 - Recall: 0.9600 - accuracy: 0.9642 - loss: 0.1134 - val_AUC: 0.9472 - val_Precision: 0.7792 - val_Recall: 0.7391 - val_accuracy: 0.7589 - val_loss: 0.8310 - learning_rate: 1.5000e-04
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.65455
# 23/23 - 1s - 40ms/step - AUC: 0.9885 - Precision: 0.9531 - Recall: 0.9531 - accuracy: 0.9531 - loss: 0.2121 - val_AUC: 0.9477 - val_Precision: 0.7759 - val_Recall: 0.7391 - val_accuracy: 0.7628 - val_loss: 0.8274 - learning_rate: 1.5000e-04
# Epoch 31/50
#
# Epoch 31: val_loss improved from 0.65455 to 0.60570, saving model to model_best.keras
# 23/23 - 20s - 885ms/step - AUC: 0.9983 - Precision: 0.9609 - Recall: 0.9497 - accuracy: 0.9552 - loss: 0.1248 - val_AUC: 0.9678 - val_Precision: 0.8215 - val_Recall: 0.8004 - val_accuracy: 0.8063 - val_loss: 0.6057 - learning_rate: 1.5000e-04
# Epoch 32/50
#
# Epoch 32: val_loss improved from 0.60570 to 0.59320, saving model to model_best.keras
# 23/23 - 13s - 547ms/step - AUC: 0.9991 - Precision: 0.9688 - Recall: 0.9688 - accuracy: 0.9688 - loss: 0.0976 - val_AUC: 0.9686 - val_Precision: 0.8235 - val_Recall: 0.8024 - val_accuracy: 0.8123 - val_loss: 0.5932 - learning_rate: 1.5000e-04
# Epoch 33/50
#
# Epoch 33: val_loss improved from 0.59320 to 0.52747, saving model to model_best.keras
# 23/23 - 22s - 968ms/step - AUC: 0.9981 - Precision: 0.9681 - Recall: 0.9628 - accuracy: 0.9662 - loss: 0.1020 - val_AUC: 0.9745 - val_Precision: 0.8337 - val_Recall: 0.8123 - val_accuracy: 0.8142 - val_loss: 0.5275 - learning_rate: 1.5000e-04
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.52747
# 23/23 - 1s - 40ms/step - AUC: 0.9987 - Precision: 0.9688 - Recall: 0.9688 - accuracy: 0.9688 - loss: 0.0907 - val_AUC: 0.9742 - val_Precision: 0.8340 - val_Recall: 0.8142 - val_accuracy: 0.8182 - val_loss: 0.5324 - learning_rate: 1.5000e-04
# Epoch 35/50
#
# Epoch 35: val_loss improved from 0.52747 to 0.46432, saving model to model_best.keras
# 23/23 - 42s - 2s/step - AUC: 0.9990 - Precision: 0.9778 - Recall: 0.9731 - accuracy: 0.9752 - loss: 0.0816 - val_AUC: 0.9777 - val_Precision: 0.8612 - val_Recall: 0.8340 - val_accuracy: 0.8498 - val_loss: 0.4643 - learning_rate: 1.5000e-04
# Epoch 36/50
#
# Epoch 36: val_loss improved from 0.46432 to 0.46417, saving model to model_best.keras
# 23/23 - 17s - 720ms/step - AUC: 1.0000 - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0337 - val_AUC: 0.9762 - val_Precision: 0.8648 - val_Recall: 0.8340 - val_accuracy: 0.8498 - val_loss: 0.4642 - learning_rate: 1.5000e-04
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.46417
# 23/23 - 9s - 386ms/step - AUC: 0.9993 - Precision: 0.9737 - Recall: 0.9690 - accuracy: 0.9711 - loss: 0.0765 - val_AUC: 0.9768 - val_Precision: 0.8545 - val_Recall: 0.8360 - val_accuracy: 0.8458 - val_loss: 0.5018 - learning_rate: 1.5000e-04
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.46417
# 23/23 - 1s - 37ms/step - AUC: 0.9987 - Precision: 0.9531 - Recall: 0.9531 - accuracy: 0.9531 - loss: 0.1170 - val_AUC: 0.9771 - val_Precision: 0.8525 - val_Recall: 0.8340 - val_accuracy: 0.8458 - val_loss: 0.4947 - learning_rate: 1.5000e-04
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.46417
# 23/23 - 10s - 438ms/step - AUC: 0.9984 - Precision: 0.9722 - Recall: 0.9655 - accuracy: 0.9704 - loss: 0.0903 - val_AUC: 0.9794 - val_Precision: 0.8809 - val_Recall: 0.8478 - val_accuracy: 0.8715 - val_loss: 0.4644 - learning_rate: 1.5000e-04
# Epoch 40/50
#
# Epoch 40: val_loss improved from 0.46417 to 0.45291, saving model to model_best.keras
# 23/23 - 19s - 811ms/step - AUC: 0.9998 - Precision: 0.9844 - Recall: 0.9844 - accuracy: 0.9844 - loss: 0.0611 - val_AUC: 0.9798 - val_Precision: 0.8884 - val_Recall: 0.8656 - val_accuracy: 0.8715 - val_loss: 0.4529 - learning_rate: 1.5000e-04
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.45291
# 23/23 - 10s - 423ms/step - AUC: 0.9984 - Precision: 0.9730 - Recall: 0.9683 - accuracy: 0.9704 - loss: 0.0873 - val_AUC: 0.9756 - val_Precision: 0.8465 - val_Recall: 0.8063 - val_accuracy: 0.8221 - val_loss: 0.5094 - learning_rate: 1.5000e-04
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.45291
# 23/23 - 1s - 33ms/step - AUC: 1.0000 - Precision: 1.0000 - Recall: 0.9844 - accuracy: 0.9844 - loss: 0.0594 - val_AUC: 0.9739 - val_Precision: 0.8388 - val_Recall: 0.8024 - val_accuracy: 0.8162 - val_loss: 0.5265 - learning_rate: 1.5000e-04
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.45291
# 23/23 - 9s - 394ms/step - AUC: 0.9985 - Precision: 0.9854 - Recall: 0.9800 - accuracy: 0.9841 - loss: 0.0632 - val_AUC: 0.9777 - val_Precision: 0.8583 - val_Recall: 0.8261 - val_accuracy: 0.8399 - val_loss: 0.4915 - learning_rate: 1.5000e-04
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.45291
# 23/23 - 1s - 31ms/step - AUC: 1.0000 - Precision: 0.9844 - Recall: 0.9844 - accuracy: 0.9844 - loss: 0.0209 - val_AUC: 0.9768 - val_Precision: 0.8577 - val_Recall: 0.8221 - val_accuracy: 0.8379 - val_loss: 0.4976 - learning_rate: 1.5000e-04
# Epoch 45/50
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.2500001068692655e-05.
#
# Epoch 45: val_loss did not improve from 0.45291
# 23/23 - 8s - 334ms/step - AUC: 0.9993 - Precision: 0.9820 - Recall: 0.9786 - accuracy: 0.9807 - loss: 0.0561 - val_AUC: 0.9791 - val_Precision: 0.8531 - val_Recall: 0.8261 - val_accuracy: 0.8360 - val_loss: 0.4704 - learning_rate: 1.5000e-04
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.45291
# 23/23 - 1s - 30ms/step - AUC: 1.0000 - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0321 - val_AUC: 0.9792 - val_Precision: 0.8513 - val_Recall: 0.8261 - val_accuracy: 0.8360 - val_loss: 0.4703 - learning_rate: 2.2500e-05
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.45291
# 23/23 - 10s - 419ms/step - AUC: 0.9996 - Precision: 0.9793 - Recall: 0.9773 - accuracy: 0.9786 - loss: 0.0628 - val_AUC: 0.9800 - val_Precision: 0.8600 - val_Recall: 0.8379 - val_accuracy: 0.8478 - val_loss: 0.4653 - learning_rate: 2.2500e-05
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.45291
# 23/23 - 1s - 38ms/step - AUC: 1.0000 - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0444 - val_AUC: 0.9801 - val_Precision: 0.8600 - val_Recall: 0.8379 - val_accuracy: 0.8458 - val_loss: 0.4636 - learning_rate: 2.2500e-05
# Epoch 49/50
#
# Epoch 49: val_loss improved from 0.45291 to 0.43207, saving model to model_best.keras
# 23/23 - 26s - 1s/step - AUC: 0.9998 - Precision: 0.9868 - Recall: 0.9821 - accuracy: 0.9848 - loss: 0.0457 - val_AUC: 0.9811 - val_Precision: 0.8637 - val_Recall: 0.8518 - val_accuracy: 0.8577 - val_loss: 0.4321 - learning_rate: 2.2500e-05
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.43207
# 23/23 - 1s - 41ms/step - AUC: 1.0000 - Precision: 1.0000 - Recall: 1.0000 - accuracy: 1.0000 - loss: 0.0169 - val_AUC: 0.9811 - val_Precision: 0.8637 - val_Recall: 0.8518 - val_accuracy: 0.8577 - val_loss: 0.4325 - learning_rate: 2.2500e-05
# Model saved to Google Drive at registered_models/model_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 635ms/step
# Registered model 'DenseNet121' already exists. Creating a new version of this model...
# Created version '4' of model 'DenseNet121'.
# Model run logged to MLflow with run_id: 4578c369e5634a8ebc48de3f7196a13f

# %% [markdown]
# ### 🧑🏽‍💻✨ Access to the MLFLOW UI ✨🧑🏽‍💻

# %%
# run tracking UI in the background
get_ipython().system_raw("mlflow ui --backend-store-uri sqlite:///mlruns.db --port 5000 &")# run tracking UI in the background

# %%
# Terminate open tunnels if they exist
ngrok.kill()

# Setting the authtoken (optional)
NGROK_AUTH_TOKEN = "2kD0rcbkl66GfLcWrG5GeU0GZ1w_7x9onfXmmEUvwCS3pBWs6"  # Replace with your actual ngrok auth token
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open an HTTPs tunnel on port 5000 for http://localhost:5000
public_url = ngrok.connect(5000, bind_tls=True)
print("MLflow Tracking UI:", public_url)
# Out:
# MLflow Tracking UI: NgrokTunnel: "https://7483-34-82-170-168.ngrok-free.app" -> "http://localhost:5000"
